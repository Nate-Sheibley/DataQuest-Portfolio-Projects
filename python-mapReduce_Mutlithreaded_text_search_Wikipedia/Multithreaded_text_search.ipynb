# %% [markdown]
# # Exploration into building a search function
#
# Use a download of wikipedia pages as the data source
#
# Build a function that searches for a target string, a simple grep analogue
#
# Output a CSV file that contains the path, line, character index, and context of the searched string
#
# This will be done using a multithreaded approach, my first independant attempt at multithreading.
#
# The 4 thread approach completed the task 2.5x faster than single thread on my machine.

# %%
import os
import math
import functools
from multiprocessing import Pool
import pandas as pd
import time
#random used to random sample some fo the data
import random
random.seed(10)

# %%
folder_name = 'wiki'
file_names = os.listdir('wiki')
print(len(file_names), 'files')
with open(os.path.join(folder_name, file_names[0])) as f:
    lines = [lines for lines in f.readlines()]
file_names[:5]
# Out:
# 1805 files
# ['2023_Challenger_Banque_Nationale_de_Saguenay_%E2%80%93_Singles.html',
#  'Constitutio_domus_regis.html',
#  'Jonathan_Biss.html',
#  'Setanta_Golf.html',
#  'Ivanka_Ninova.html']

# %% [markdown]
# Create a function that counts the number of lines
# ---
# First step
#
# Build a simple multithreaded function that accesses the number of lines per file
#
# Intent: simply get the multithreaded functionality working.

# %%
def make_chunks(data, num_chunks):
    chunk_size = math.ceil(len(data) / num_chunks)
    return [data[i:i+chunk_size] for i in range(0, len(data), chunk_size)]

def map_reduce(data, num_processes, mapper, reducer):
    chunks = make_chunks(data, num_processes)
    with Pool(num_processes) as pool:
        chunk_results = pool.map(mapper, chunks)
    return functools.reduce(reducer, chunk_results)

# %%
def map_num_lines(file_names_chunk):
    num_lines = 0
    for file_name in file_names_chunk:
        with open(os.path.join(folder_name, file_name)) as file:
            num_lines += len(file.readlines())
    return num_lines

def reducer_num_lines(num_lines1, num_lines2):
    return num_lines1 + num_lines2

# %% [markdown]
# Total lines : 1685770
# ---
# 1805 files used. The scraping script only scrapes 1000 pages. It was mistakenly ran twice and exited partway through the second one.

# %%
total_lines = map_reduce(file_names, 4, map_num_lines, reducer_num_lines)
total_lines
# Out:
# 1685770

# %% [markdown]
# Modify the Function to give a search result
# ---
#
# Returns a dict that contains {'filename':[list of rows with the searched term]}
#
# Intent: increase funtion complexity to include the search term

# %%
target = input("Search for string: ")
# Out:
# Search for string:  blue

# %%
def map_search_lines(file_names_chunk):
    search_result = {}
    for file_name in file_names_chunk:
        with open(os.path.join(folder_name, file_name)) as file:
            indices = [index for index, line in enumerate(file.readlines()) if target in line]
        search_result[file_name] = indices    
    return search_result

def reducer_search_lines(search_result1, search_result2):
    merged = {}
    merged.update(search_result1)
    merged.update(search_result2)
    return merged

# %%
total_target_string = map_reduce(file_names, 4, map_search_lines, reducer_search_lines)

# %%
sample = [random.choice(list(total_target_string.keys())) for _ in range(10)]

# %%
# random sample some of this dict
# each dict value contains a list of row indicies that contain the target word in that file.
# random sample 10 items of the dict, 1805 items

[f'{key} : {total_target_string[key]}' for key in sample]
# Out:
# ['Ed_McClanahan.html : []',
#  'Kasbah_Boulaouane.html : []',
#  'Freddy_Bravo.html : []',
#  'Dennis_Dreith.html : []',
#  'Morgan_%2B4%2B.html : []',
#  'Ben_Verbong.html : []',
#  'Innocent_Man_(Mark_Morrison_album).html : [7, 543, 549, 558, 623, 662]',
#  'Corfu.html : [1831, 2121, 2122]',
#  'Ever_Since_Darwin.html : []',
#  'Nadine_Ellis.html : []']

# %% [markdown]
# Update search to be case insensative
# ---
#
# Improve search function
#
# Intent: Find additional hits were found when the search was done in a case insensative manner

# %%
def map_search_case_insensative(file_names_chunk):
    search_result = {}
    for file_name in file_names_chunk:
        with open(os.path.join(folder_name, file_name)) as file:
            indices = [index for index, line in enumerate(file.readlines()) if target.lower() in line.lower()]
        search_result[file_name] = indices    
    return search_result

def reducer_search_case_insensative(search_result1, search_result2):
    merged = {}
    merged.update(search_result1)
    merged.update(search_result2)
    return merged

# %%
total_case_insensative = map_reduce(file_names, 4, map_search_case_insensative, reducer_search_case_insensative)
# random sample some of this dict
# each dict value contains a list of row indicies that contain the target word in that file. case insensative
# random sample 10 items of the dict, 1805 items
[f'{key} : {total_case_insensative[key]}' for key in sample]
# Out:
# ['Ed_McClanahan.html : []',
#  'Kasbah_Boulaouane.html : []',
#  'Freddy_Bravo.html : [537]',
#  'Dennis_Dreith.html : []',
#  'Morgan_%2B4%2B.html : []',
#  'Ben_Verbong.html : []',
#  'Innocent_Man_(Mark_Morrison_album).html : [7, 543, 549, 558, 623, 662]',
#  'Corfu.html : [1827, 1831, 1929, 2121, 2122, 2688]',
#  'Ever_Since_Darwin.html : []',
#  'Nadine_Ellis.html : [913]']

# %%
#Additional hits per line that had multiple hits
#A results of 1 means there was 1 additional (2 total) hits in this line

case_inse_additional = {}
for key in total_case_insensative:
    additional = [i for i in total_case_insensative[key] if i not in total_target_string[key]]
    case_inse_additional[key] = len(additional)
    
    if case_inse_additional[key] != 0:
        print(key, ':', case_inse_additional[key])
# Out:
# Sundargarh_Lok_Sabha_constituency.html : 1
# Washington%27s_Headquarters_State_Historic_Site.html : 1
# Billy_Rich.html : 4
# 2020_Conference_USA_women%27s_basketball_tournament.html : 1
# Guo_Longchen.html : 1
# Tekkonkinkreet.html : 2
# Shadow_Man_(song).html : 2
# 2nd_Minnesota_Cavalry_Regiment.html : 1
# UTSA_Roadrunners_football.html : 1
# Allan_W._Eckert.html : 3
# Sherpix.html : 3
# Indie_Game_Developer_Network.html : 3
# Deaths_in_January_2008.html : 1
# 2022%E2%80%9323_Czech_First_League.html : 1
# Adriaan_Carelse.html : 3
# Muhammad_Salaam.html : 2
# Renato_Marazzi.html : 1
# Vadim_Tolstopyatov.html : 1
# James_McKnight_(American_football).html : 1
# Mus%C5%8D_Jikiden_Eishin-ry%C5%AB.html : 2
# 1900_Lafayette_football_team.html : 1
# 1897%E2%80%9398_Irish_League.html : 1
# 2023%E2%80%9324_Tweede_Divisie.html : 1
# Kar%C3%A8n_Shainyan.html : 1
# The_Venetian_Las_Vegas.html : 6
# Hampton_Down_Stone_Circle.html : 1
# When_Christmas_Comes.html : 1
# Thonny.html : 1
# 1972%E2%80%9373_Georgetown_Hoyas_men%27s_basketball_team.html : 2
# When_Willie_Comes_Marching_Home.html : 1
# Edison_Bell.html : 1
# Terror_Tomb.html : 1
# 2003_European_Judo_Championships.html : 1
# The_Walkmen.html : 2
# Springport,_Indiana.html : 1
# Golden_Valley_Four-Ball.html : 1
# Miley_Cyrus.html : 2
# 1997%E2%80%9398_FA_Premier_League.html : 3
# Richtmyer_Peak.html : 1
# Amos_N._Wilson.html : 1
# The_Free_Design.html : 1
# Battle_of_Farmington,_Tennessee.html : 1
# 2014%E2%80%9315_Southern_Miss_Lady_Eagles_basketball_team.html : 2
# 1956_Middle_Tennessee_Blue_Raiders_football_team.html : 137
# Seo_Jung-won.html : 16
# IBC_Airways.html : 1
# The_Wild_Heart_(album).html : 3
# BlueOS.html : 29
# CMLL_Super_Viernes_(October_2012).html : 3
# Jacqueline_Obradors.html : 4
# 2023%E2%80%9324_St._John%27s_Red_Storm_men%27s_basketball_team.html : 4
# Heinkel_Kabine.html : 1
# Republicans_for_Bulgaria.html : 1
# Patriot_Express.html : 1
# 1999%E2%80%932000_Los_Angeles_Clippers_season.html : 1
# Ridgedale_High_School.html : 1
# Leonid_Zakharov_(rower).html : 2
# SS_Ixion.html : 1
# Cruz_Salmer%C3%B3n_Acosta.html : 1
# Nancy_Nathanson.html : 1
# Nick_Banks.html : 1
# Irumashi_Station.html : 1
# 1988%E2%80%9389_Northern_Football_League.html : 2
# Shadows_of_Blue.html : 31
# Pali_village.html : 2
# Paul_Zimmerman_(sportswriter).html : 1
# Atsuko_Tanaka_(animator).html : 3
# %C3%98ivind_H%C3%B8ibak.html : 3
# Argo_(1800_ship).html : 1
# Colonization_of_the_Moon.html : 3
# James_W._Kynes.html : 2
# Pages_River.html : 2
# Cross_Timbers.html : 2
# 2023_Kansas_City_Current_season.html : 1
# Steve_Barta.html : 1
# Tony_Pignone.html : 2
# 1934%E2%80%9335_Campionat_de_Catalunya.html : 1
# Nutida_musik.html : 1
# TV.html : 2
# Blue_Rodeo_Live_in_Stratford.html : 56
# Counter-Strike:_Condition_Zero.html : 1
# Adolphus_Hailstork.html : 2
# 1978_Rose_Bowl.html : 2
# Ernest_Fernando.html : 1
# Wade,_Oklahoma.html : 1
# USS_LST-467.html : 3
# Omaha_Ford_Motor_Company_Assembly_Plant.html : 1
# The_Secrets_of_the_Immortal_Nicholas_Flamel.html : 2
# Corfu.html : 3
# Arthur_Curry_(DC_Extended_Universe).html : 7
# Silver_%27n_Brass.html : 11
# Gilbert_Hotel.html : 1
# Ken_Gibler.html : 2
# List_of_Atlanta_Thrashers_draft_picks.html : 2
# Dreamin%27_Man_Live_%2792.html : 2
# Kenji_Yoshino.html : 1
# Second_Kuomintang-Communist_Civil_War.html : 1
# Zec_des_Anses.html : 1
# Cambridge,_Ontario.html : 2
# Tetsuya_(musician).html : 2
# Better_Than_Chocolate.html : 1
# Smith_Corner,_Pennsylvania.html : 1
# Hari_Kondabolu.html : 1
# Baugh_Mountain.html : 1
# Blue_flu.html : 45
# Suffolk_Wildlife_Trust.html : 1
# Jessica_Burkhart.html : 1
# Meridian_High_School_(Idaho).html : 1
# Volkswagen_Touareg.html : 17
# Louis_Croenen.html : 5
# 1974%E2%80%9375_Seattle_SuperSonics_season.html : 1
# Doug_McIntosh.html : 1
# Philip_Attipoe.html : 1
# Keith_Urban_(1991_album).html : 1
# Michael_Strahan.html : 1
# In_Love_and_Death.html : 1
# The_Arthur_Terry_School.html : 1
# History_of_Dedham,_Massachusetts,_1635%E2%80%931699.html : 1
# Shepherds_Bush_Empire_(album).html : 6
# Blue_Commandos_in_Action.html : 30
# 2019%E2%80%9320_Eerste_Divisie.html : 1
# Song_Il-kook.html : 1
# Dave_Adams_(musician).html : 1
# Tsukuba_International_School.html : 1
# German_submarine_U-569.html : 1
# 2023_Food_City_Dirt_Race.html : 1
# Edith_Smith_(police_officer).html : 1
# Elena_Reiche.html : 2
# 2004_Chinese_FA_Cup.html : 4
# Harrison_Chad.html : 4
# Virginia_Cherrill.html : 1
# Nadine_Ellis.html : 1
# Ledringhem.html : 1
# Ninpiden.html : 1
# KK_Zagreb.html : 1
# Xenosaga:_The_Animation.html : 1
# List_of_the_Hollies_members.html : 1
# Chris_Plys.html : 4
# Sanchez_of_Bel_Air.html : 1
# Otto_Robert_Frisch.html : 1
# Washington_Urrutia.html : 1
# Ballycowan_(barony).html : 1
# Theodoros_Chatzitheodorou.html : 3
# Basic_Blues_Magoos.html : 41
# Sete_Gibernau.html : 1
# 1950_Guatemalan_parliamentary_election.html : 1
# KeuPa_HT.html : 1
# Nikolas_Antoniou.html : 4
# McDonnell_120_Flying_Crane.html : 1
# 1989_Delaware_Fightin%27_Blue_Hens_football_team.html : 146
# Josef_Kramol%C3%ADn.html : 1
# Cho_U.html : 1
# School_District_44_North_Vancouver.html : 1
# Turbo_(software).html : 1
# Syrmaticus.html : 2
# Long_Yellow_Road_(Toshiko_Akiyoshi_Trio_album).html : 2
# Stephen_Spangler.html : 6
# Jason_Wilson_(musician).html : 2
# Alive_35_World_Tour.html : 4
# St._Sebastian_River_Preserve_State_Park.html : 3
# Timeline_of_C%C3%B3rdoba,_Spain.html : 1
# 1900%E2%80%9301_Football_League.html : 2
# Burritts_Rapids.html : 1
# Tamer_%C5%9Eahin.html : 2
# Michael_Houser_(ice_hockey).html : 1
# 1976_Madison_Dukes_football_team.html : 2
# Elmira,_Kansas.html : 2
# Hose_Station_No._4.html : 1
# Two_Sides_of_Dave_Van_Ronk.html : 9
# Jimmie_Foxx.html : 2
# Peter_A._Hemmy.html : 1
# Keith_Moon.html : 2
# Microbial_loop.html : 1
# Lorenzo_Parente.html : 1
# Armada_(capoeira).html : 2
# Caia_van_Maasakker.html : 3
# 2013%E2%80%9314_Toronto_Maple_Leafs_season.html : 11
# Auxiliary_Territorial_Service.html : 1
# Memphis_to_New_York_Spirit.html : 9
# Workplace_OS.html : 1
# Jackie_Wilson_discography.html : 6
# 88th_Grey_Cup.html : 3
# Jason_R%C3%BCesch.html : 2
# Organic_(Joe_Cocker_album).html : 2
# Hazaribagh.html : 1
# Michael_Almereyda.html : 1
# Julien_Genre.html : 1
# Tim_Bothwell.html : 10
# Mohamed_Nasihin_Nubil_Ibrahim.html : 2
# Stuttgart_Surge.html : 1
# Evans,_West_Virginia.html : 1
# Farhad_Aslani.html : 2
# Fayetteville_High_School_(Arkansas).html : 2
# Flag_of_Scotland.html : 3
# Folk_Songs_of_Our_Land.html : 1
# Francine_Prose.html : 2
# Francis_Rimbert.html : 2
# Freddy_Bravo.html : 1
# FRM_II.html : 1
# Gabriela_Soto.html : 4
# Gardner_(Cassatt)_Held_by_His_Mother.html : 1

# %% [markdown]
# Improve search result
# ---
# Return Given additional hits per line, return a list of tuples that provide (line index, string index) per hit per file
#
# This will allow us to use a loop to grab context from the files later

# %%
#Added helper function to clean up the list comprehension used for bulding the search result tuples

def get_index_tuples(line, line_num):
    index_tuples = [(line_num, index) for index in range(len(line)) if line.startswith(target.lower(), index)]
    return index_tuples

def map_search_line_tuples(file_names_chunk):
    search_result = {}
    for file_name in file_names_chunk:
        with open(os.path.join(folder_name, file_name)) as file:
            index_tuples = [get_index_tuples(line.lower(), index) for index, line in enumerate(file.readlines()) if target.lower() in line.lower()]
        search_result[file_name] = index_tuples    
    return search_result

def reducer_search_line_tuples(search_result1, search_result2):
    merged = {}
    merged.update(search_result1)
    merged.update(search_result2)
    return merged

# %%
total_tuples = map_reduce(file_names, 4, map_search_line_tuples, reducer_search_line_tuples)

[f'{key} : {total_tuples[key]}' for key in sample]
# Out:
# ['Ed_McClanahan.html : []',
#  'Kasbah_Boulaouane.html : []',
#  'Freddy_Bravo.html : [[(537, 495), (537, 516), (537, 661), (537, 682), (537, 760), (537, 781)]]',
#  'Dennis_Dreith.html : []',
#  'Morgan_%2B4%2B.html : []',
#  'Ben_Verbong.html : []',
#  'Innocent_Man_(Mark_Morrison_album).html : [[(7, 41)], [(543, 3948), (543, 4617)], [(549, 100)], [(558, 243)], [(623, 1227), (623, 1252)], [(662, 441), (662, 493), (662, 529)]]',
#  'Corfu.html : [[(1827, 364), (1827, 400)], [(1831, 734), (1831, 781), (1831, 801)], [(1929, 861), (1929, 921), (1929, 954)], [(2121, 139), (2121, 180)], [(2122, 109), (2122, 128)], [(2688, 443), (2688, 904)]]',
#  'Ever_Since_Darwin.html : []',
#  'Nadine_Ellis.html : [[(913, 24)]]']

# %% [markdown]
# Construct into a functional datatype
# --
# Data structure:|File Path |Line Index | String Index| String Context|
#
# Build a non-mutlithreaded implementation first, then construct into a multithreaded function.
#
# Compare time taken to do the context calls and build the dataframe

# %%
#Build non-multithreaded DataFrame constructor
start = time.time()
rows = []
for file_name in total_tuples:
    with open(os.path.join(folder_name, file_name)) as file:
        lines = file.readlines()
        for line_list in total_tuples[file_name]:
            for tup in line_list:
                context = lines[tup[0]][tup[1]-20 : tup[1]+10+len(target)]
                row = [''.join([folder_name, '/', file_name]), tup[0], tup[1], context]
                rows.append(row)
                
df = pd.DataFrame(rows, columns=['File', 'Line', 'Index', 'Context'])
print(time.time()-start, 's')
df
# Out:
# 0.19721603393554688 s
#                                                    File  Line  Index  \
# 0           wiki/Sundargarh_Lok_Sabha_constituency.html   726     41
# 1     wiki/Washington%27s_Headquarters_State_Histori...   975     19
# 2     wiki/Washington%27s_Headquarters_State_Histori...   975     44
# 3     wiki/Washington%27s_Headquarters_State_Histori...   975     62
# 4                       wiki/2024_Tour_of_the_Alps.html  1973     28
# ...                                                 ...   ...    ...
# 3223                             wiki/Gary_Waddock.html  1160   1819
# 3224                             wiki/Gary_Waddock.html  1261    522
# 3225                             wiki/Gary_Waddock.html  1261   1010
# 3226                             wiki/Gary_Waddock.html  1261   1376
# 3227                             wiki/Gary_Waddock.html  1261   1763
#
#                                  Context
# 0     ; background-color: Blue;" data-so
# 1
# 2     kin_(horse)" title="Blueskin (hors
# 3     ="Blueskin (horse)">Blueskin</a></
# 4     e="background:dodgerblue;"><a href
# ...                                  ...
# 3223  e,inset -1px -1px 0 blue; width: 8
# 3224  e="background:mediumblue; color:wh
# 3225  =";background:mediumblue; color:wh
# 3226  =";background:mediumblue; color:wh
# 3227  =";background:mediumblue; color:wh
#
# [3228 rows x 4 columns]

# %%
#Build multithreaded DataFrame constructor
#Could not pass the dictionary or keys directly as Python dicionary keys are not ordered, and can not be subscripted
def map_to_df(file_names_chunk):
    rows = []
    for file_name in file_names_chunk:
        with open(os.path.join(folder_name, file_name)) as file:
            lines = file.readlines()
            for line_list in total_tuples[file_name]:
                for tup in line_list:
                    context = lines[tup[0]][tup[1]-20 : tup[1]+10+len(target)]
                    row = [''.join([folder_name, '/', file_name]), tup[0], tup[1], context]
                    rows.append(row)
    return rows

def reducer_to_df(rows1, rows2):
    merged = []
    merged.extend(rows1)
    merged.extend(rows2)
    return merged

start = time.time()

to_df = map_reduce(file_names, 4, map_to_df, reducer_to_df)
df = pd.DataFrame(to_df, columns=['File', 'Line', 'Index', 'Context'])

print(time.time()-start, 's')
df
# Out:
# 0.07882881164550781 s
#                                                    File  Line  Index  \
# 0           wiki/Sundargarh_Lok_Sabha_constituency.html   726     41
# 1     wiki/Washington%27s_Headquarters_State_Histori...   975     19
# 2     wiki/Washington%27s_Headquarters_State_Histori...   975     44
# 3     wiki/Washington%27s_Headquarters_State_Histori...   975     62
# 4                       wiki/2024_Tour_of_the_Alps.html  1973     28
# ...                                                 ...   ...    ...
# 3223                             wiki/Gary_Waddock.html  1160   1819
# 3224                             wiki/Gary_Waddock.html  1261    522
# 3225                             wiki/Gary_Waddock.html  1261   1010
# 3226                             wiki/Gary_Waddock.html  1261   1376
# 3227                             wiki/Gary_Waddock.html  1261   1763
#
#                                  Context
# 0     ; background-color: Blue;" data-so
# 1
# 2     kin_(horse)" title="Blueskin (hors
# 3     ="Blueskin (horse)">Blueskin</a></
# 4     e="background:dodgerblue;"><a href
# ...                                  ...
# 3223  e,inset -1px -1px 0 blue; width: 8
# 3224  e="background:mediumblue; color:wh
# 3225  =";background:mediumblue; color:wh
# 3226  =";background:mediumblue; color:wh
# 3227  =";background:mediumblue; color:wh
#
# [3228 rows x 4 columns]

# %%
df.to_csv()
#supress to_csv output
None
